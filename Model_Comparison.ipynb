# %% [markdown]
# ## PROPHET FACEBOOK
#
# STREGNTH:
#
#
# Ease of Utilize:
# Prophet is profoundly instinctive and doesn't require profound factual information, which makes it open to a wide run of clients, counting those less experienced in time arrangement investigation.
#
# Regularity & Drift Discovery:
# Prophet exceeds expectations in capturing clear regular patterns (every day, week after week, annually) and long-term development designs, particularly in trade estimating. It's outlined for applications like request and deals determining.
#
# Lost Information & Exceptions Taking care of:
# Prophet can naturally handle lost information and exceptions successfully, making it strong for real-world loud datasets. Clients do not ought to clean information broadly some time recently applying the show.
# Customizable Seasonalities:
#
# Prophet permits for the customization of regular components by altering parameters or indicating occasions, which progresses exactness in businesses with patterned patterns (e.g., retail, coordinations).
#
# Taking care of Occasions (Holidays/Special Events):
# It's especially well-suited for determining around holidays and known occasions that can be effectively indicated within the demonstrate.
#
#
# #WEAKNESSES:
#
#
# Constrained Non-Linear Modeling:
# Whereas it performs well for straight patterns and well-defined regularity, Prophet battles with profoundly complex, non-linear connections that will exist in information, particularly in cases like stock advertise forecasts or chaotic information.
#
# Presumption of Added substance Connections:
# Prophet essentially accept that the impacts of drift and regularity are added substance. Whereas it can be arranged for multiplicative regularity, this may not continuously fit the reality of certain information designs.
#
# Constrained Adaptability in Highlight Designing:
# Prophet centers intensely on time-based designs, and whereas it allows a few adaptability, it isn't as versatile to complex multivariate time arrangement as models like LSTM.
#
# Prophet is particularly effective in business applications where seasonality and trends dominate, such as sales and demand forecasting. In scenarios with clear seasonality, it often outperforms more complex models, thanks to its simplicity and robust handling of holiday effects.

# %% [markdown]
# ## **ARIMA**
#
# STRENGTH:
#
#
#
# ARIMA (AutoRegressive Coordinates Moving Normal) model is established in well-established measurable hypothesis. this model is exceedingly interpretable and give significant parameters such as auto-regressive terms and moving normal slacks.
#
# Great for Direct Connections:
# ARIMA is especially solid when the fundamental connections within the information are direct. On the off chance that the information appears steady designs over time, ARIMA can capture them viably.
#
# Consistency of Stationary Information:
# ARIMA is great when information can be made stationary (i.e., when there's no slant or regular variety). For shorter-term estimates in money related information or other normally stationary datasets, ARIMA tends to perform well.
#
# Customizable:
# ARIMA permits clients to physically indicate parameters (p, d, q) to make strides the show fit, whereas ETS permits customization for blunder, slant, and regularity components.
#
# WEAKNESS
#
# Requires Information Stationarity:
# ARIMA requires the information to be stationary, meaning that the cruel and fluctuation of the time arrangement ought to not alter over time. Information with solid patterns or regularity must be differenced some time recently fitting, which includes complexity.
#
# Battles with Non-Linear Designs:
# ARIMA models accept direct connections, which limits their appropriateness in datasets with non-linear patterns or complex intelligent between factors.
#
# Not Vigorous to Lost Information or Exceptions:
# Not at all like Prophet, conventional models are delicate to lost information and exceptions, requiring more broad information cleaning some time recently modeling.

# %% [markdown]
# ## LSTM
#
# STRENGTH:
#
#
# Non-Linear Design Acknowledgment:
# LSTMs exceed expectations at distinguishing complicated non-linear designs and long-term conditions inside successive information. They can demonstrate more complex connections that conventional factual models may ignore.
#
# Multivariate Capabilities:
# LSTMs can handle different highlights (like promoting campaigns, competitor costs, stock levels) at the same time, making them capable in circumstances where a few variables impact the target variable (e.g., request determining).
#
# Adaptability:
# LSTMs can handle shifting time steps and are profoundly adaptable with regard to the input information arrange. This makes them versatile to a assortment of determining issues, counting multivariate time arrangement with numerous input highlights.
#
# Long Memory:
# LSTMs are planned to hold data from long time arrangements, which is basic for errands where verifiable setting traversing weeks or months impacts the display (e.g., item request with regularity + slant).
#
#
# WEAKNESSES:
#
# Information and Preparing Necessities:
# LSTMs require huge sums of information for preparing to precisely capture designs. Without adequate chronicled information, the demonstrate may battle to generalize, driving to problematic comes about.
#
# Complexity and Resource-Intensive:
# Preparing an LSTM show can be computationally costly, particularly for long groupings and expansive datasets. Moreover, hyperparameter tuning (e.g., grouping length, learning rate) is frequently required, which includes to the complexity.
# Interpretability:
# Not at all like less complex models like ARIMA or Prophet, LSTMs work more like a “black box,” which can make it troublesome to decipher how the demonstrate comes to its forecasts. This may be a drawback in commerce scenarios where partners require clear, interpretable bits of knowledge.
