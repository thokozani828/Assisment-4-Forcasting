# %%
 # Import the pandas library
import pandas as pd 
from prophet import Prophet
import warnings
from prophet.plot import plot_plotly


# Load the dataset
df = pd.read_csv("C:/Users/Admin/Desktop/Test 4/Historical Product Demand.csv")

# Display the first few rows of the dataset
df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date Order_Demand
# 0  Product_0993    Whse_J     Category_028  2012/7/27         100
# 1  Product_0979    Whse_J     Category_028  2012/1/19         500
# 2  Product_0979    Whse_J     Category_028   2012/2/3         500
# 3  Product_0979    Whse_J     Category_028   2012/2/9         500
# 4  Product_0979    Whse_J     Category_028   2012/3/2         500

# %% [markdown]
# ##APPLYING DATA PREPROCCESSING

# %%
# Convert the 'Order Date' column to datetime format
df ['Date'] = pd.to_datetime (df['Date'])
df
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 0        Product_0993    Whse_J     Category_028 2012-07-27         100
# 1        Product_0979    Whse_J     Category_028 2012-01-19         500
# 2        Product_0979    Whse_J     Category_028 2012-02-03         500
# 3        Product_0979    Whse_J     Category_028 2012-02-09         500
# 4        Product_0979    Whse_J     Category_028 2012-03-02         500
# ...               ...       ...              ...        ...          ...
# 1048570  Product_1791    Whse_J     Category_006 2016-04-27        1000
# 1048571  Product_1974    Whse_J     Category_006 2016-04-27           1
# 1048572  Product_1787    Whse_J     Category_006 2016-04-28        2500
# 1048573  Product_0901    Whse_J     Category_023 2016-10-07          50
# 1048574  Product_0704    Whse_J     Category_001 2016-06-27           4
#
# [1048575 rows x 5 columns]

# %%
category_filter = 'Category_028'
frame = df[df['Product_Category'] == category_filter]

# Display only 'Date' and 'Order_Demand' columns
frame = frame[['Date', 'Order_Demand']]

# Rename columns to fit Prophet's requirements
frame.columns = ['ds', 'y']

# Convert the 'y' column to numeric, setting errors='coerce' will turn any non-numeric values into NaN
frame['y'] = pd.to_numeric(frame['y'], errors='coerce')

# Drop rows with NaN values, as Prophet cannot handle them
frame = frame.dropna()

print(frame.head())
# Out:
#           ds      y
# 0 2012-07-27  100.0
# 1 2012-01-19  500.0
# 2 2012-02-03  500.0
# 3 2012-02-09  500.0
# 4 2012-03-02  500.0

# %% [markdown]
# ##CREATING THE TIME SERIA MODEL

# %%
# Initialize the Prophet model and fit it to the data
m = Prophet(interval_width=0.95)
training_run = m.fit(frame)
# Out:
# 20:32:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:32:22 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ##EVALUATION OF THE MORDEL

# %%
# Make sure 'future' is defined
future = m.make_future_dataframe(periods=30, freq='D')  # Create a DataFrame for the next 30 days

# Generate the forecast
forecast = m.predict(future)
forecast.tail()
# Out:
#              ds        trend    yhat_lower    yhat_upper  trend_lower  \
# 1466 2017-01-30  2090.957984 -12646.687451  15098.892089  2034.047636
# 1467 2017-01-31  2088.890250 -12765.311414  14436.947863  2027.229322
# 1468 2017-02-01  2086.822516 -12224.085333  14922.026029  2021.176604
# 1469 2017-02-02  2084.754783 -12397.202004  14803.340493  2014.233804
# 1470 2017-02-03  2082.687049 -12509.091682  14935.517959  2008.819897
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 1466  2141.782663    -1189.974725          -1189.974725          -1189.974725
# 1467  2146.187136    -1190.750910          -1190.750910          -1190.750910
# 1468  2148.108043    -1222.977820          -1222.977820          -1222.977820
# 1469  2150.414667     -712.899225           -712.899225           -712.899225
# 1470  2151.608713    -1276.478420          -1276.478420          -1276.478420
#
#           weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# ...

# %%
warnings.filterwarnings("ignore")

# Plot the forecast using Plotly
plot1 = m.plot(forecast)

# %%
plot2 = m.plot_components(forecast)
